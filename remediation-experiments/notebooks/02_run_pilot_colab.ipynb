# %% [markdown]
# # Run Pilot Remediation Experiment
#
# This notebook is a placeholder for the first model-running pass. Use it after selecting model providers and API keys.

# %%
# If running in a fresh Colab runtime, clone the repo first.
# !git clone https://github.com/nancyotero-projects/math-misconceptions.git
# %cd math-misconceptions

# !pip install -r requirements.txt

# %%
# !python remediation-experiments/scripts/run_experiment.py \
  --split remediation-experiments/data/splits/pilot_20.json \
  --prompt remediation-experiments/prompts/diagnosis_first.md

# %% [markdown]
# Next implementation step: add provider-specific model calls and save one JSONL record per model response.
