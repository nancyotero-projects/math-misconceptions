# %% [markdown]
# # Prepare Remediation Dataset
#
# Run this notebook in Colab from a cloned copy of the GitHub repository. The reusable logic lives in `remediation-experiments/scripts/prepare_dataset.py`.

# %%
# If running in a fresh Colab runtime, clone the repo first.
# !git clone https://github.com/nancyotero-projects/math-misconceptions.git
# %cd math-misconceptions

# !pip install -r requirements.txt

# %%
# !python remediation-experiments/scripts/prepare_dataset.py

# %%
import json
from pathlib import Path

cases_path = Path('remediation-experiments/data/processed/remediation_cases.jsonl')
first_case = json.loads(cases_path.read_text().splitlines()[0])
first_case.keys(), first_case['case_id'], first_case['topic']
